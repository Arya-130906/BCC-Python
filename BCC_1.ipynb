# %%
# why python is dynamically
math=40
pi=3.14
name="Arya Paunikar"
print(type(math))
print(type(pi))
print(type(name))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#what is type casting
print(2+2)
print("2"+"2")
val1= int(input("enter 1st value:"))
val2=int(input("enter 2nd value:"))
print(val1+val2)
# Out:
# 4
# 22
# enter 1st value:2
# enter 2nd value:3
# 5

# %%
print(int(3.14))
print(int(True))
print(int(False))
print(int("4"))
# Out:
# 3
# 1
# 0
# 4

# %%
print(float(3))
print(float(True))
print(float(False))
print(float(4.22))
print(float("4"))
# Out:
# 3.0
# 1.0
# 0.0
# 4.22
# 4.0

# %%
print(complex(3))
print(complex(12.5))
print(complex(True))
print(complex(False))
print(complex("5"))
print(complex("5.6"))
print(complex(5,-3))
print(complex(True,False))
# Out:
# (3+0j)
# (12.5+0j)
# (1+0j)
# 0j
# (5+0j)
# (5.6+0j)
# (5-3j)
# (1+0j)

# %%
print(bool(0))
print(bool(15))
print(bool(3.14))
print(bool(0.0))
print(bool(1+2j))
print(bool(0+0j))
print(bool(-1))
print(bool(False))
print(bool(True))
# Out:
# False
# True
# True
# False
# True
# False
# True
# False
# True

# %%
#wap to write si
principleamt=10000
roi=10
duration=1
si=((principleamt*roi*duration)/100)
print("si=",si)
# Out:
# si= 1000.0

# %%
#wap to accept a centrigrade temp and convert it into fareh
celsius=int(input("enter temp in celsius:"))
fahrenheit=(celsius*1.8)+32
print("The temp in fahrenheit is:",fahrenheit)
# Out:
# enter temp in celsius:48
# The temp in fahrenheit is: 118.4

# %%
#swapping of two numbers
a=int(input("enter 1st value:"))
b=int(input("enter 2nd value:"))
temp=a
a=b
b=temp
print(a,b)
# Out:
# enter 1st value:5
# enter 2nd value:7
# 7 5

# %%
a=int(input("enter 1st value:"))
b=int(input("enter 2nd value:"))
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# enter 1st value:6
# enter 2nd value:8
# 8 6

# %%
h=20
print("inch=",h*12)
print("cm=",h*2.54)
# Out:
# inch= 240
# cm= 50.8

# %%
num=123
a=num%10
num=num//10
b=num%10
c=num//10
rev=a*100+b*10+c
print(rev)
# Out:
# 321

# %%
num = 1234567
a = num % 10
num = num // 10
b = num % 10
num = num // 10
c = num % 10
num = num // 10
d = num % 10
num = num // 10
e = num % 10
num = num // 10
f = num % 10
num = num // 10
g = num % 10
rev = a*1000000 + b*100000 + c*10000 + d*1000 + e*100 + f*10 + g
print(rev)
# Out:
# 7654321
