# %%
#Nested function
def outerFunction():
  print("this is my outer function") # second
  def innerFunction():
    print("inner Function")
  innerFunction() #third
outerFunction() #first execution starts from here
# Out:
# this is my outer function
# inner Function

# %%
#WAP to perform arithmetic operation using functional programming approach
#Functions helps us to achieve modularity approach
import sys  #has predefined function that helps to stop the program

def addition(num1, num2):  #called function
    print("Addition=", num1 + num2)

def substraction(num1, num2):  #called function
    print("Subtraction=", num1 - num2)

def multiplication(num1, num2):  #called function
    print("Multiplication=", num1 * num2)

def division(num1, num2):  #called function
    print("Division=", num1 / num2)

while True:
    print("1.Addition")
    print("2.Subtraction")
    print("3.Multiplication")
    print("4.Division")
    print("5.Exit")
    choice = int(input("Enter your choice from above options: "))
    if choice == 5:
        sys.exit()
    val1 = int(input("Enter first value: "))
    val2 = int(input("Enter second value: "))
    if choice == 1:
        addition(val1, val2)
    elif choice == 2:
        substraction(val1, val2)
    elif choice == 3:
        multiplication(val1, val2)
    elif choice == 4:
        division(val1, val2)
    else:
        #sys.exit()
        print("You have entered wrong choice.")

# %%
#WAP to perform arithmetic operation using functional programming approach
#Functions helps us to achieve modularity approach
#import sys
#has predefined function that helps to stop the program
def addition(num1, num2): #called function
 print("Addition=", num1 + num2)

def substraction(num1, num2): #called function
 print("Subtraction=", num1 - num2)

def multiplication(num1, num2): #called function
 print("Multiplication=", num1 * num2)

def division(num1, num2): #called function
 print("Division=", num1 / num2)

while True:
    print("1.Addition")
    print("2.Subtraction")
    print("3.Multiplication")
    print("4.Division")
    print("5.Exit")
    choice = int(input("Enter your choice from above options: "))
    if choice == 5:
        print("Exit")
        break
    val1 = int(input("Enter first value: "))
    val2 = int(input("Enter second value: "))
    if choice == 1:
        addition(val1, val2)
    elif choice == 2:
        substraction(val1, val2)
    elif choice == 3:
        multiplication(val1, val2)
    elif choice == 4:
        division(val1, val2)
    else:
        print("You have entered wrong choice.")
# Out:
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Exit
# Enter your choice from above options: 1
# Enter first value: 23
# Enter second value: 67
# Addition= 90
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Exit
# Enter your choice from above options: 5
# Exit

# %%
#input=prashant is a good programmer.
#WAP to count the word
#output=5
name="prashant is a good programmer"
count=1
for i in name:#i=0
  if i==' ':
    count+=1
  else:
    continue
print("Total word count=",count)
# Out:
# Total word count= 5

# %%
init_tuple=()
print(init_tuple.__len__())
# Out:
# 0

# %%
init_tuple_a='a','b'
init_tuple_b=('a','b')
print(init_tuple_a==init_tuple_b)
#in tuple datatype circle bracket is also considered as tuple
# Out:
# True

# %%
init_tuple_a='1','2'
init_tuple_b=('3','4')
print(init_tuple_a+init_tuple_b)
id(init_tuple_a)
id(init_tuple_b)
# Out:
# ('1', '2', '3', '4')
# 138221913597376

# %%
l=[1,2,3]
init_tuple=('Python',)*(l.__len__()-l[::-1][0])
print(init_tuple)
# Out:
# ()

# %%
init_tuple=('Python')*3
print(type(init_tuple))
#if init_tuple = ('Python,') * 3 then tuple
# Out:
# <class 'str'>

# %%
init_tuple=(1,)*3
init_tuple[0]=2
print(init_tuple)
#output:TypeError:'tuple' object does not support item assignment
#because tuple is immutable and cannot be changed

# %%
init_tuple=((1,2),)*7
print(len(init_tuple[3:8]))
#((1,2),)*7 creates a tuple with 7 elements.init_tuple[3:8] slices 4 elements → so len(...) = 4.
#tuple contains 7 elements then we slice them from index 3 to 8 where 8 is excluded
# Out:
# 4

# %%
#Replacing a string with another string
#s.replace(oldstring,newstring)
#inside s,every occurence of oldstring will be replaced with newstring
s=""
s1=s.replace("difficult","easy")
print(s1)
#All occurence will be replaced
s="ababababababab"
s1=s.replace("a","b")
print(s1)
#output explanation:replace("a","b") replaces every occurrence of "a" in the string with "b" and returns a new string (original unchanged).So "ababababababab" becomes all "b" characters.
# Out:
# bbbbbbbbbbbbbb

# %%
#Removing spaces from the string:
#1.rstrip()===>To remove spaces at right hand side
#2.lstrip()===>To remove spaces at left hand side
#3.sstrip()===>To remove spaces from both side
city=input("Enter your city name:")
scity=city.strip()
if scity=='Hyderabad':
    print("Hello Hyderbadi..Adab")
elif scity=='Chennai':
    print("Hello Madrasi...Vanakkam")
elif scity=='Bangalore':
    print("Hello Kannadiga...Shubhodaya")
else:
  print("Your entered city is invalid")
# Out:
# Enter your city name:Nagpur
# Your entered city is invalid

# %%
#List comprehension
s=[i*i for i in range(1,11)]#i=1
print(s)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
#Power calculation
val=[2**i for i in range(1,6)]#i=1,2,3,4,5
print(val)
# Out:
# [2, 4, 8, 16, 32]

# %%
val2=[i for i in s if i%2==0]#i=1
print(val2)
# Out:
# [4, 16, 36, 64, 100]

# %%
#Dictionary comprehension
squares={x:x*x for x in range(1,6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
doubles={x:2*x for x in range(1,6)}
print(doubles)
# Out:
# {1: 2, 2: 4, 3: 6, 4: 8, 5: 10}
